# %%
# !pip install bertopic
# Out:
# Requirement already satisfied: bertopic in /usr/local/lib/python3.10/dist-packages (0.15.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.23.5)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.10/dist-packages (from bertopic) (0.8.33)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (0.5.4)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.66.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.15.0)
# Requirement already satisfied: cython<3,>=0.27 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (0.29.36)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.11.3)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (23.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.34.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.16.0+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.17.3)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.10)
# Requirement already satisfied: tbb>=2019.0 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (2021.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.12.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (67.7.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2023.6.3)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.7)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)

# %%
# !pip install bertopic[visualization]
# Out:
# Requirement already satisfied: bertopic[visualization] in /usr/local/lib/python3.10/dist-packages (0.15.0)
# WARNING: bertopic 0.15.0 does not provide the extra 'visualization'
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic[visualization]) (1.23.5)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.10/dist-packages (from bertopic[visualization]) (0.8.33)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from bertopic[visualization]) (0.5.4)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic[visualization]) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic[visualization]) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic[visualization]) (4.66.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from bertopic[visualization]) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic[visualization]) (5.15.0)
# Requirement already satisfied: cython<3,>=0.27 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic[visualization]) (0.29.36)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic[visualization]) (1.11.3)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic[visualization]) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic[visualization]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic[visualization]) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic[visualization]) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic[visualization]) (23.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic[visualization]) (3.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (4.34.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.16.0+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.17.3)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic[visualization]) (0.56.4)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic[visualization]) (0.5.10)
# Requirement already satisfied: tbb>=2019.0 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic[visualization]) (2021.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.12.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (4.5.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic[visualization]) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic[visualization]) (67.7.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic[visualization]) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2023.6.3)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (0.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic[visualization]) (8.1.7)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic[visualization]) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (1.3.0)

# %%
#import packages

import pandas as pd
import numpy as np
from bertopic import BERTopic
import string

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('./drive/MyDrive/NLP2023/Reviews_Filter.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.head(40)
# Out:
#     Id   ProductId          UserId                      ProfileName  \
# 0    1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1    2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2    3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3    4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4    5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# 5    6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
# 6    7  B006K2ZZ7K  A1SP2KVKFXXRU1                David C. Sullivan
# 7    8  B006K2ZZ7K  A3JRGQVEQN31IQ               Pamela G. Williams
# 8    9  B000E7L2R4  A1MZYO9TZK0BBI                         R. James
# 9   10  B00171APVA  A21BT40VZCCYT4                    Carol A. Reed
# 10  11  B0001PB9FE  A3HDKO7OW0QNK4                     Canadian Fan
# 11  12  B0009XLVG0  A2725IB4YY9JEB           A Poeng "SparkyGoHome"
# 12  13  B0009XLVG0   A327PCT23YH90                               LT
# 13  14  B001GVISJM  A18ECVX2RJ7HUE                  willie "roadie"
# 14  15  B001GVISJM  A2MUGFV2TDQ47K              Lynrie "Oh HELL no"
# 15  16  B001GVISJM  A1CZX3CP8IKQIJ                     Brian A. Lee
# 16  17  B001GVISJM  A3KLWF6WQ5BNYO                   Erica Neathery
# 17  18  B001GVISJM   AFKW14U97Z6QO                            Becca
# 18  19  B001GVISJM  A2A9X58G2GTBLP                          Wolfee1
# 19  20  B001GVISJM  A3IV7CL2C13K2U                             Greg
# 20  21  B001GVISJM  A1WO0KGLPR5PV6                         mom2emma
# 21  22  B001GVISJM   AZOF9E17RGZH8                   Tammy Anderson
# 22  23  B001GVISJM   ARYVQL4N737A1                    Charles Brown
# 23  24  B001GVISJM   AJ613OLZZUG7V                           Mare's
# 24  25  B001GVISJM  A22P2J09NJ9HKE      S. Cabanaugh "jilly pepper"
# 25  26  B001GVISJM  A3FONPR03H3PJS     Deborah S. Linzer "Cat Lady"
# 26  27  B001GVISJM  A3RXAU2N8KV45G                           lady21
# 27  28  B001GVISJM   AAAS38B98HMIK                     Heather Dube
# 28  29  B00144C10S  A2F4LZVGFLD1OB                           DaisyH
# 29  30  B0001PB9FY  A3HDKO7OW0QNK4                     Canadian Fan
# 30  31  B003F6UO7K   AFM0O9480F04W                          Sherril
# 31  32  B003F6UO7K  A31OQO709M20Y7          Molly V. Smith "staral"
# 32  33  B001EO5QW8   AOVROBZ8BNTP7                        S. Potter
# 33  34  B001EO5QW8  A3PMM0NFVEJGK9         Megan "Bad at Nicknames"
# 34  35  B001EO5QW8  A2EB6OGOWCRU5H                       CorbyJames
# 35  36  B001EO5QW8  A2CI0RLADCRKPF                       T. J. Ryan
# 36  37  B001EO5QW8  A1MYS9LFFBIYKM         Abby Chase "gluten free"
# 37  38  B001EO5QW8  A3MGP2E1ZZ6GRB             Zardoz "focuspuller"
# 38  39  B001EO5QW8  A2GHZ2UTV2B0CD                      JERRY REITH
# 39  40  B001EO5QW8   AO80AC8313NIZ                        kYpondman
#
#     HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                      1                       1      5  1303862400
# 1                      0                       0      1  1346976000
# 2                      1                       1      4  1219017600
# 3                      3                       3      2  1307923200
# 4                      0                       0      5  1350777600
# 5                      0                       0      4  1342051200
# 6                      0                       0      5  1340150400
# 7                      0                       0      5  1336003200
# 8                      1                       1      5  1322006400
# 9                      0                       0      5  1351209600
# 10                     1                       1      5  1107820800
# 11                     4                       4      5  1282867200
# 12                     1                       1      1  1339545600
# 13                     2                       2      4  1288915200
# 14                     4                       5      5  1268352000
# 15                     4                       5      5  1262044800
# 16                     0                       0      2  1348099200
# 17                     0                       0      5  1345075200
# 18                     0                       0      5  1324598400
# 19                     0                       0      5  1318032000
# 20                     0                       0      5  1313452800
# 21                     0                       0      5  1308960000
# 22                     0                       0      5  1304899200
# 23                     0                       0      5  1304467200
# 24                     0                       0      5  1295481600
# 25                     0                       0      5  1288310400
# 26                     0                       1      1  1332633600
# 27                     0                       1      4  1331856000
# 28                     0                       0      5  1338854400
# 29                     1                       1      5  1107820800
# 30                     0                       0      5  1297641600
# 31                     0                       1      5  1288310400
# 32                    19                      19      4  1163376000
# 33                    13                      13      4  1166313600
# 34                     9                       9      5  1175212800
# 35                     3                       3      4  1210464000
# 36                     2                       2      5  1190851200
# 37                     1                       1      5  1238457600
# 38                     0                       0      4  1350777600
# 39                     0                       0      5  1317168000
#
#                                               Summary  \
# 0                               Good Quality Dog Food
# 1                                   Not as Advertised
# 2                               "Delight" says it all
# 3                                      Cough Medicine
# 4                                         Great taffy
# 5                                          Nice Taffy
# 6       Great!  Just as good as the expensive brands!
# 7                              Wonderful, tasty taffy
# 8                                          Yay Barley
# 9                                    Healthy Dog Food
# 10                    The Best Hot Sauce in the World
# 11  My cats LOVE this "diet" food better than thei...
# 12               My Cats Are Not Fans of the New Food
# 13                                  fresh and greasy!
# 14                       Strawberry Twizzlers - Yummy
# 15           Lots of twizzlers, just what you expect.
# 16                                         poor taste
# 17                                           Love it!
# 18                                 GREAT SWEET CANDY!
# 19                            Home delivered twizlers
# 20                                       Always fresh
# 21                                          TWIZZLERS
# 22                                 Delicious product!
# 23                                          Twizzlers
# 24                      Please sell these in Mexico!!
# 25                             Twizzlers - Strawberry
# 26                                    Nasty No flavor
# 27                        Great Bargain for the Price
# 28                                             YUMMY!
# 29                    The Best Hot Sauce in the World
# 30                                     Great machine!
# 31                                THIS IS MY TASTE...
# 32                       Best of the Instant Oatmeals
# 33                                       Good Instant
# 34          Great Irish oatmeal for those in a hurry!
# 35                                         satisfying
# 36                        Love Gluten Free Oatmeal!!!
# 37                                       it's oatmeal
# 38                      GOOD WAY TO START THE DAY....
# 39                          Wife's favorite Breakfast
#
#                                                  Text
# 0   bought several vitality canned food products f...
# 1   product arrived labeled jumbo salted peanutsth...
# 2   confection around centuries light pillowy citr...
# 3   looking secret ingredient robitussin believe f...
# 4   great taffy great price wide assortment yummy ...
# 5   wild hair taffy ordered five pound taffy enjoy...
# 6   saltwater taffy great flavors soft chewy candy...
# 7   taffy good soft chewy flavors amazing would de...
# 8   right mostly sprouting cats grass love rotate ...
# 9   healthy food good digestion also good small pu...
# 10  dont know cactus tequila unique combination in...
# 11  boys needed lose weight didnt food floor chubb...
# 12  cats happily eating felidae platinum years sha...
# 13  good flavor came securely packed fresh delicio...
# 14  strawberry twizzlers guilty pleasure yummy pou...
# 15  daughter loves twizzlers shipment pounds reall...
# 16  love eating good watching looking movies sweet...
# 17  satisfied twizzler purchase shared others enjo...
# 18  twizzlers strawberry childhood favorite candy ...
# 19  candy delivered fast purchased reasonable pric...
# 20  husband twizzlers addict weve bought many time...
# 21  bought husband currently overseas loves appare...
# 22  remember buying candy quality hasnt dropped ye...
# 23      love candy weight watchers back still craving
# 24  lived miss twizzlers back visit someone visits...
# 25  product received advertisedbr hrefhttpwwwamazo...
# 26                candy flavor plan chewy would never
# 27  glad amazon carried batteries hard time findin...
# 28  diabetic needs watch sugar intake father simpl...
# 29  dont know cactus tequila unique combination in...
# 30  never huge coffee however mother purchased lit...
# 31  offer great price great taste thanks amazon se...
# 32  mccanns instant oatmeal great must oatmeal scr...
# 33  good instant oatmeal best oatmeal brand uses c...
# 34  instant oatmeal become soggy minute water hits...
# 35  mccanns instant irish oatmeal variety pack reg...
# 36  celiac disease product lifesaver could better ...
# 37  else need know oatmeal instant make half lowfa...
# 38  visiting friend nate morning coffee came stora...
# 39  ordered wife reccomended daughter almost every...

# %%
def clean_text(text):
  delete_dict ={sp_character: '' for sp_character in string.punctuation}
  delete_dict[' '] = ' '
  table = str.maketrans(delete_dict)
  text1 = text.translate(table)
  textArr = text1.split()
  text2 = ' '.join([w for w in textArr if (not w.isdigit() and (not w.isdigit() and len(w)>3))])

  return text2.lower()

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df.dropna(axis = 0, how = 'any', inplace=True)

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  bought several vitality canned food products f...
# 1      Not as Advertised  product arrived labeled jumbo salted peanutsth...
# 2  "Delight" says it all  confection around centuries light pillowy citr...
# 3         Cough Medicine  looking secret ingredient robitussin believe f...
# 4            Great taffy  great taffy great price wide assortment yummy ...

# %%
df['Text'] = df['Text'].apply(clean_text)

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
def remove_stopwords(text):
  textArr = text.split(' ')
  rem_text = " ".join([i for i in textArr if i not in stop_words])
  return rem_text

df['Text'] = df['Text'].apply(remove_stopwords)

# %%
df['Text'].head()
# Out:
# 0    bought several vitality canned food products f...
# 1    product arrived labeled jumbo salted peanutsth...
# 2    confection around centuries light pillowy citr...
# 3    looking secret ingredient robitussin believe f...
# 4    great taffy great price wide assortment yummy ...
# Name: Text, dtype: object

# %%
model = BERTopic(verbose=True)

docs = df.Text.to_list()
topics, probabilities = model.fit_transform(docs)
# Out:
# Batches:   0%|          | 0/469 [00:00<?, ?it/s]
# 2023-10-24 08:51:14,677 - BERTopic - Transformed documents to Embeddings
# 2023-10-24 08:51:32,787 - BERTopic - Reduced dimensionality
# 2023-10-24 08:51:33,449 - BERTopic - Clustered reduced embeddings

# %%
model.get_topic_freq().head(20)
# Out:
#      Topic  Count
# 0       -1   5352
# 4        0    689
# 44       1    368
# 31       2    347
# 13       3    306
# 50       4    249
# 43       5    238
# 23       6    198
# 5        7    180
# 6        8    165
# 149      9    156
# 112     10    153
# 15      11    152
# 2       12    141
# 82      13    135
# 7       14    133
# 60      15    128
# 30      16    114
# 24      17    113
# 96      18    110

# %%
model.get_topic(0)
# Out:
# [('dogs', 0.029561651796392655),
#  ('treats', 0.029134923494835305),
#  ('newmans', 0.018312807700423137),
#  ('treat', 0.016148471630914027),
#  ('food', 0.012910946267436833),
#  ('organic', 0.011069934100384616),
#  ('break', 0.010832363166817476),
#  ('lamb', 0.009390136557261132),
#  ('puppy', 0.008492062823541553),
#  ('barley', 0.007727405598426963)]

# %%
model.get_topic(1)
# Out:
# [('cocoa', 0.06755399606803805),
#  ('chocolate', 0.046126294607546935),
#  ('grove', 0.017479789922406515),
#  ('dark', 0.01688762235786757),
#  ('stephens', 0.015419703758858925),
#  ('square', 0.015119177333112532),
#  ('keurig', 0.015028192255550202),
#  ('milk', 0.01456413580136276),
#  ('chocolates', 0.013583544881787698),
#  ('watery', 0.010731117807918095)]

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="aadfa003-f71a-4b88-823f-302f2ff4e447" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aadfa003-f71a-4b88-823f-302f2ff4e447")) {                    Plotly.newPlot(                        "aadfa003-f71a-4b88-823f-302f2ff4e447",                        [{"customdata":[[0,"dogs | treats | newmans | treat | food",689],[1,"cocoa | chocolate | grove | dark | stephens",368],[2,"orange | juice | soda | tangerine | switch",347],[3,"baby | earths | daughter | organic | food",306],[4,"rinds | pork | microwave | cook | bacon",249],[5,"crackers | cracker | glutino | broken | gluten",238],[6,"teas | green | iced | stash | water",198],[7,"sauce | sauces | heat | spicy | bottle",180],[8,"cats | food | felidae | kitten | kitty",165],[9,"filter | cups | kcup | disposable | disposakups",156],[10,"decaf | coffee | decaffeinated | melitta | caffeine",153],[11,"popcorn | kernels | popper | popped | white",152],[12,"candy | candies | gummy | bears | gummi",141],[13,"coconut | pineapple | water | coco | vita",135],[14,"snack | calories | snacks | calorie | crisps",133],[15,"coffee | melitta | coffees | grind | blend",128],[16,"salt | pink | himalayan | grinder | salts",114],[17,"noodles | pasta | tofu | shirataki | orzo",113],[18,"jerky | beef | links | jack | sticks",110],[19,"cereal | fiber | cereals | granola | mueslix",109],[20,"cake | fondant | frosting | cakes | fondarific",108],[21,"kcups | kcup | flavored | bold | coffee",98],[22,"gift | chocolates | christmas | liquor | chocolate",97],[23,"tablets | lemons | tablet | lemon | sour",97],[24,"china | made | jerky | chicken | treats",96],[25,"soup | soups | lobster | chicken | canned",94],[26,"flavor | husband | flavors | taste | really",89],[27,"coffee | price | amazon | stores | local",89],[28,"beans | vanilla | extract | bean | vacuum",89],[29,"drawer | space | counter | keurig | storage",83],[30,"icicle | windows | plug | audio | recording",81],[31,"bags | loose | leaf | lipton | pack",80],[32,"ghee | grassfed | butter | grass | organic",75],[33,"almonds | diamond | roasted | blue | almond",72],[34,"freezer | trays | tray | baby | freeze",70],[35,"peanuts | virginia | nuts | royal | beer",70],[36,"sugar | brown | splenda | cubes | agave",68],[37,"pill | pockets | pills | pocket | meds",67],[38,"plant | plants | ants | flies | venus",67],[39,"truffle | truffles | saffron | infused | white",64],[40,"kettle | chips | potato | chip | onion",59],[41,"waffle | waffles | pancake | belgian | stonewall",58],[42,"milk | goat | goats | cows | powdered",56],[43,"arrived | order | exactly | fast | described",56],[44,"syrup | maple | grade | syrups | vermont",55],[45,"popchips | chips | variety | pepper | salt",55],[46,"cookies | cookie | chocolate | nuts | paleo",55],[47,"jamaica | jamaican | flavored | coffee | crazy",54],[48,"nuts | macadamia | cashews | mauna | rancid",54],[49,"grocery | stores | find | store | walmart",53],[50,"hazelnut | coffee | flavored | hawaiian | flavor",51],[51,"formula | similac | baby | infant | milk",51],[52,"morning | coffee | strong | wake | husband",51],[53,"grass | grow | cats | seeds | planted",47],[54,"olive | olives | virgin | oils | dirty",47],[55,"vanilla | french | creamer | wolfgang | puck",47],[56,"energy | shot | caffeine | steaz | boost",47],[57,"altoids | peppermint | mints | wintergreen | mint",46],[58,"bisquick | pancakes | gluten | free | glutenfree",46],[59,"chia | seeds | navitas | oatmeal | naturals",46],[60,"bold | medium | smooth | dark | coffee",45],[61,"oatmeal | oats | mccanns | instant | steel",45],[62,"cookies | cookie | broken | delta | crumbs",44],[63,"emerils | starbucks | mountain | bold | emeril",44],[64,"licorice | panda | black | so ...

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="36c027bb-5fc9-47d6-97fb-6431436751ba" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36c027bb-5fc9-47d6-97fb-6431436751ba")) {                    Plotly.newPlot(                        "36c027bb-5fc9-47d6-97fb-6431436751ba",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.012910946267436833,0.016148471630914027,0.018312807700423137,0.029134923494835305,0.029561651796392655],"y":["food  ","treat  ","newmans  ","treats  ","dogs  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.015419703758858925,0.01688762235786757,0.017479789922406515,0.046126294607546935,0.06755399606803805],"y":["stephens  ","dark  ","grove  ","chocolate  ","cocoa  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.029957907576820146,0.031503593255390476,0.037786097413594066,0.03981547409526913,0.044780733291223604],"y":["switch  ","tangerine  ","soda  ","juice  ","orange  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.013858867574295013,0.015037185380084068,0.01757225730137248,0.025571275307670824,0.03828462457555303],"y":["food  ","organic  ","daughter  ","earths  ","baby  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.017467749700693355,0.018806755704775045,0.057203000543622665,0.06778229177094847,0.07096023917357491],"y":["bacon  ","cook  ","microwave  ","pork  ","rinds  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.015025454737514633,0.016167589684337787,0.01712206833175126,0.04718929215882547,0.10818254070583927],"y":["gluten  ","broken  ","glutino  ","cracker  ","crackers  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.013113455078008538,0.014113124873001705,0.023766039274790072,0.03535385362255378,0.0399302683149359],"y":["water  ","stash  ","iced  ","green  ","teas  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.018147669352358186,0.019626263217301106,0.02252164690179302,0.028056201021590843,0.07964931864734265],"y":["bottle  ","spicy  ","heat  ","sauces  ","sauce  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.444444 ...

# %%
model = BERTopic(nr_topics=40)

# %%
topics, probabilities = model.fit_transform(docs)
# Out:
# 2023-10-24 08:59:52,127 - BERTopic - Transformed documents to Embeddings
# 2023-10-24 09:00:11,021 - BERTopic - Reduced dimensionality
# 2023-10-24 09:00:11,699 - BERTopic - Clustered reduced embeddings
# 2023-10-24 09:00:14,876 - BERTopic - Reduced number of topics from 173 to 40

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bee399bc-7d22-4333-b901-995efa2da936" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bee399bc-7d22-4333-b901-995efa2da936")) {                    Plotly.newPlot(                        "bee399bc-7d22-4333-b901-995efa2da936",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.018735281769401556,0.021295976923966797,0.02175615647973834,0.022487910091070228,0.061550678106825935],"y":["keurig  ","chocolate  ","cocoa  ","kcups  ","coffee  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.018419526691771226,0.019145566831482944,0.02356280513232162,0.029995806363878774,0.05502876469515004],"y":["baby  ","potato  ","popcorn  ","crackers  ","chips  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.025300057276172308,0.02535187172152691,0.026452994718906817,0.03227176824043388,0.03274720988708208],"y":["drink  ","sugar  ","soda  ","orange  ","juice  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.01843169176975099,0.024901008114924763,0.027667483990458885,0.027815283609283693,0.02938119505151819],"y":["soup  ","microwave  ","sauce  ","rinds  ","pork  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.02125503589424923,0.021301576322451908,0.02180662642569959,0.023699576616370698,0.02597384273021635],"y":["arrived  ","amazon  ","price  ","shipping  ","product  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.024690240198795513,0.02566221428822391,0.03561610004404816,0.043362861839321615,0.05124282564932371],"y":["treat  ","cats  ","food  ","dogs  ","treats  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.02564139283140592,0.026030601800525358,0.027907006601936377,0.028359598438307352,0.04812337864977624],"y":["seeds  ","chia  ","cereal  ","protein  ","milk  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.03893296560886001,0.03951757278917901,0.05898538795497121,0.0717417968506588,0.07286694812128726],"y":["jelly  ","peanut  ","nuts  ","peanuts  ","almonds  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.444444444444444 ...
